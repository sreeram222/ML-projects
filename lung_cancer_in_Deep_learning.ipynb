# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeram222/ML-projects/blob/main/lung_cancer_in_Deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/lung_cancer_examples.csv")
df
# Out:
#            Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0          John         Wick   35       3      5       4       1
# 1          John  Constantine   27      20      2       5       1
# 2        Camela     Anderson   30       0      5       2       0
# 3          Alex       Telles   28       0      8       1       0
# 4         Diego     Maradona   68       4      5       6       1
# 5     Cristiano      Ronaldo   34       0     10       0       0
# 6        Mihail          Tal   58      15     10       0       0
# 7         Kathy        Bates   22      12      5       2       0
# 8        Nicole       Kidman   45       2      6       0       0
# 9           Ray      Milland   52      18      4       5       1
# 10      Fredric        March   33       4      8       0       0
# 11          Yul      Brynner   18      10      6       3       0
# 12         Joan     Crawford   25       2      5       1       0
# ...

# %%
df.drop(["Name","Surname"],axis=1,inplace=True)
df
# Out:
#     Age  Smokes  AreaQ  Alkhol  Result
# 0    35       3      5       4       1
# 1    27      20      2       5       1
# 2    30       0      5       2       0
# 3    28       0      8       1       0
# 4    68       4      5       6       1
# 5    34       0     10       0       0
# 6    58      15     10       0       0
# 7    22      12      5       2       0
# 8    45       2      6       0       0
# 9    52      18      4       5       1
# 10   33       4      8       0       0
# 11   18      10      6       3       0
# 12   25       2      5       1       0
# 13   28      20      2       8       1
# 14   34      25      4       8       1
# 15   39      18      8       1       0
# 16   42      22      3       5       1
# 17   19      12      8       0       0
# 18   62       5      4       3       1
# 19   73      10      7       6       1
# 20   55      15      1       3       1
# 21   33       8      8       1       0
# 22   22      20      6       2       0
# ...

# %%
df.isna().sum()
# Out:
# Age       0
# Smokes    0
# AreaQ     0
# Alkhol    0
# Result    0
# dtype: int64

# %%
x=df.iloc[:,:-1]
x
# Out:
#     Age  Smokes  AreaQ  Alkhol
# 0    35       3      5       4
# 1    27      20      2       5
# 2    30       0      5       2
# 3    28       0      8       1
# 4    68       4      5       6
# 5    34       0     10       0
# 6    58      15     10       0
# 7    22      12      5       2
# 8    45       2      6       0
# 9    52      18      4       5
# 10   33       4      8       0
# 11   18      10      6       3
# 12   25       2      5       1
# 13   28      20      2       8
# 14   34      25      4       8
# 15   39      18      8       1
# 16   42      22      3       5
# 17   19      12      8       0
# 18   62       5      4       3
# 19   73      10      7       6
# 20   55      15      1       3
# 21   33       8      8       1
# 22   22      20      6       2
# 23   44       5      8       1
# 24   77       3      2       6
# 25   21      20      5       3
# 26   37      15      6       2
# 27   34      12      8       0
# 28   55      20      1       4
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0     1
# 1     1
# 2     0
# 3     0
# 4     1
# 5     0
# 6     0
# 7     0
# 8     0
# 9     1
# 10    0
# 11    0
# 12    0
# 13    1
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# 19    1
# 20    1
# 21    0
# 22    0
# 23    0
# 24    1
# 25    0
# 26    0
# 27    0
# 28    1
# 29    1
# 30    0
# 31    1
# 32    1
# 33    1
# 34    0
# 35    0
# 36    1
# 37    1
# 38    0
# 39    0
# 40    1
# 41    0
# 42    1
# 43    1
# 44    0
# 45    0
# 46    0
# 47    0
# 48    1
# 49    1
# 50    0
# 51    1
# 52    1
# 53    0
# 54    0
# 55    1
# 56    1
# 57    1
# 58    0
# Name: Result, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
x=mm.fit_transform(x)
x
# Out:
# array([[0.28813559, 0.08823529, 0.44444444, 0.5       ],
#        [0.15254237, 0.58823529, 0.11111111, 0.625     ],
#        [0.20338983, 0.        , 0.44444444, 0.25      ],
#        [0.16949153, 0.        , 0.77777778, 0.125     ],
#        [0.84745763, 0.11764706, 0.44444444, 0.75      ],
#        [0.27118644, 0.        , 1.        , 0.        ],
#        [0.6779661 , 0.44117647, 1.        , 0.        ],
#        [0.06779661, 0.35294118, 0.44444444, 0.25      ],
#        [0.45762712, 0.05882353, 0.55555556, 0.        ],
#        [0.57627119, 0.52941176, 0.33333333, 0.625     ],
#        [0.25423729, 0.11764706, 0.77777778, 0.        ],
#        [0.        , 0.29411765, 0.55555556, 0.375     ],
#        [0.11864407, 0.05882353, 0.44444444, 0.125     ],
#        [0.16949153, 0.58823529, 0.11111111, 1.        ],
#        [0.27118644, 0.73529412, 0.33333333, 1.        ],
#        [0.3559322 , 0.52941176, 0.77777778, 0.125     ],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from tensorflow import keras
from keras.models import Sequential
ann=Sequential([keras.layers.Dense(6,activation="relu"),
                keras.layers.Dense(7,activation="relu"),
                keras.layers.Dense(1,activation="sigmoid")])

# %%
ann.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
ann.fit(x_train,y_train,batch_size=10,epochs=100)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4894 - loss: 0.6812
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4478 - loss: 0.6768
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4616 - loss: 0.6716
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4602 - loss: 0.6627
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5005 - loss: 0.6583
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5185 - loss: 0.6535
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4908 - loss: 0.6538
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4283 - loss: 0.6527
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5074 - loss: 0.6392
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4324 - loss: 0.6483
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4685 - loss: 0.6319
# Epoch 12/100
# ...

# %%
y_pred=ann.predict(x_test)
y_pred=(y_pred>0.5)
y_pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# array([[ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)*100
# Out:
# 100.0

# %%
ann.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 6)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 7)              │            49 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │             8 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 263 (1.03 KB)
#  Trainable params: 87 (348.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 176 (708.00 B)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[8, 0],
#        [0, 4]])

# %%
z=ann.predict(mm.transform([[2,3,5,8]]))
print(z)

if z>0.5:
  print("cancer")
else:
  print("cancer free")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# [[0.45496997]]
# cancer free
