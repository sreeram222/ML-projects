# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeram222/ML-projects/blob/main/factors_affecting_student_grades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Factors_ affecting_ university_student_grades_dataset.csv")
df
# Out:
#         Age Gender Parental_Education Family_Income Previous_Grades  \
# 0      22.0      F            College       50000.0               A
# 1      21.0      M                NaN       60000.0               A
# 2      19.0      M            College       75000.0               C
# 3      21.0      M            College       60000.0               A
# 4      19.0    NaN                NaN       40000.0             NaN
# ...     ...    ...                ...           ...             ...
# 10059  20.0    NaN       Some College       75000.0               A
# 10060  19.0      M            College           NaN               B
# 10061  20.0      M                NaN       30000.0               B
# 10062  21.0      F            College       50000.0               B
# 10063  18.0      F       Some College       30000.0               A
#
#        Attendance Class_Participation  Study_Hours        Major School_Type  \
# ...

# %%
df.shape
# Out:
# (10064, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10064 entries, 0 to 10063
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          9099 non-null   float64
#  1   Gender                       9085 non-null   object
#  2   Parental_Education           9102 non-null   object
#  3   Family_Income                9097 non-null   object
#  4   Previous_Grades              9120 non-null   object
#  5   Attendance                   9060 non-null   float64
#  6   Class_Participation          9098 non-null   object
#  7   Study_Hours                  9073 non-null   float64
#  8   Major                        9136 non-null   object
#  9   School_Type                  9115 non-null   object
#  10  Financial_Status             9129 non-null   object
#  11  Parental_Involvement         9118 non-null   object
# ...

# %%
df.drop(["Age","Gender","Parental_Education","Bullying"],axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# Family_Income                   967
# Previous_Grades                 944
# Attendance                     1004
# Class_Participation             966
# Study_Hours                     991
# Major                           928
# School_Type                     949
# Financial_Status                935
# Parental_Involvement            946
# Educational_Resources           935
# Motivation                      970
# Self_Esteem                     912
# Stress_Levels                   919
# School_Environment              958
# Professor_Quality               950
# Class_Size                      950
# Extracurricular_Activities      905
# Sleep_Patterns                 1016
# Nutrition                       977
# Physical_Activity               974
# Screen_Time                     944
# Educational_Tech_Use            993
# Peer_Group                      919
# Study_Space                    1007
# Learning_Style                  984
# Tutoring                        931
# ...

# %%
df["Family_Income"].value_counts()
# Out:
# Family_Income
# 50000.0    1832
# 30000.0    1832
# 60000.0    1814
# 75000.0    1810
# 40000.0    1808
# Unknown       1
# Name: count, dtype: int64

# %%
import numpy as np
df.loc[df.Family_Income=="Unknown","Family_Income"]=np.nan

# %%
df["Family_Income"].value_counts()
# Out:
# Family_Income
# 50000.0    1832
# 30000.0    1832
# 60000.0    1814
# 75000.0    1810
# 40000.0    1808
# Name: count, dtype: int64

# %%
df['Family_Income'] = pd.to_numeric(df['Family_Income'], errors='coerce')
df["Family_Income"]=df["Family_Income"].fillna(df["Family_Income"].mode()[0])

# %%
df
# Out:
#        Family_Income Previous_Grades  Attendance Class_Participation  \
# 0            50000.0               A        81.0              Medium
# 1            60000.0               A         NaN              Medium
# 2            75000.0               C        93.0              Medium
# 3            60000.0               A        86.0                 Low
# 4            40000.0             NaN        89.0                High
# ...              ...             ...         ...                 ...
# 10059        75000.0               A        78.0                 NaN
# 10060        30000.0               B         NaN              Medium
# 10061        30000.0               B        97.0              Medium
# 10062        50000.0               B        75.0              Medium
# 10063        30000.0               A        80.0                 Low
#
#        Study_Hours        Major School_Type Financial_Status  \
# 0              8.0          Law     Private              Low
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10064 entries, 0 to 10063
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Family_Income                10064 non-null  float64
#  1   Previous_Grades              9120 non-null   object
#  2   Attendance                   9060 non-null   float64
#  3   Class_Participation          9098 non-null   object
#  4   Study_Hours                  9073 non-null   float64
#  5   Major                        9136 non-null   object
#  6   School_Type                  9115 non-null   object
#  7   Financial_Status             9129 non-null   object
#  8   Parental_Involvement         9118 non-null   object
#  9   Educational_Resources        9129 non-null   object
#  10  Motivation                   9094 non-null   object
#  11  Self_Esteem                  9152 non-null   object
# ...

# %%
df1=["Previous_Grades","Class_Participation","Major","School_Type","Financial_Status","Parental_Involvement","Educational_Resources","Motivation","Self_Esteem","Stress_Levels","School_Environment","Professor_Quality","Extracurricular_Activities","Nutrition","Physical_Activity","Educational_Tech_Use","Peer_Group","Study_Space","Learning_Style","Tutoring","Mentoring","Lack_of_Interest","Sports_Participation","Grades"]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for column in df1:
  df.loc[:, column] = le.fit_transform(df.loc[:, column])

# %%
df
# Out:
#        Family_Income Previous_Grades  Attendance Class_Participation  \
# 0            50000.0               0        81.0                   2
# 1            60000.0               0         NaN                   2
# 2            75000.0               2        93.0                   2
# 3            60000.0               0        86.0                   1
# 4            40000.0               3        89.0                   0
# ...              ...             ...         ...                 ...
# 10059        75000.0               0        78.0                   3
# 10060        30000.0               1         NaN                   2
# 10061        30000.0               1        97.0                   2
# 10062        50000.0               1        75.0                   2
# 10063        30000.0               0        80.0                   1
#
#        Study_Hours Major School_Type Financial_Status Parental_Involvement  \
# ...

# %%
df["Previous_Grades"].value_counts().astype(float)
df["Class_Participation"].value_counts().astype(float)
df["Major"].value_counts().astype(float)
df["School_Type"].value_counts().astype(float)
df["Financial_Status"].value_counts().astype(float)
df["Parental_Involvement"].value_counts().astype(float)
df["Educational_Resources"].value_counts().astype(float)
df["Motivation"].value_counts().astype(float)
df["Self_Esteem"].value_counts().astype(float)
df["Stress_Levels"].value_counts().astype(float)
df["School_Environment"].value_counts().astype(float)
df["Professor_Quality"].value_counts().astype(float)
df["Extracurricular_Activities"].value_counts().astype(float)
df["Nutrition"].value_counts().astype(float)
df["Physical_Activity"].value_counts().astype(float)
df["Educational_Tech_Use"].value_counts().astype(float)
df["Peer_Group"].value_counts().astype(float)
df["Study_Space"].value_counts().astype(float)
df["Learning_Style"].value_counts().astype(float)
df["Tutoring"].value_counts().astype(float)
df["Mentoring"].value_counts().astype(float)
df["Lack_of_Interest"].value_counts().astype(float)
df["Sports_Participation"].value_counts().astype(float)
df["Grades"].value_counts().astype(float)
# Out:
# Grades
# 1    3038.0
# 2    3010.0
# 0    2976.0
# 3    1040.0
# Name: count, dtype: float64

# %%
df.isna().sum()
# Out:
# Family_Income                     0
# Previous_Grades                   0
# Attendance                     1004
# Class_Participation               0
# Study_Hours                     991
# Major                             0
# School_Type                       0
# Financial_Status                  0
# Parental_Involvement              0
# Educational_Resources             0
# Motivation                        0
# Self_Esteem                       0
# Stress_Levels                     0
# School_Environment                0
# Professor_Quality                 0
# Class_Size                      950
# Extracurricular_Activities        0
# Sleep_Patterns                 1016
# Nutrition                         0
# Physical_Activity                 0
# Screen_Time                     944
# Educational_Tech_Use              0
# Peer_Group                        0
# Study_Space                       0
# Learning_Style                    0
# Tutoring                          0
# ...

# %%
df["Attendance"].value_counts().astype(float)#mode
df["Study_Hours"].value_counts().astype(float)#mean
df["Class_Size"].value_counts().astype(float)#mean
df["Sleep_Patterns"].value_counts().astype(float)#mean
df["Screen_Time"].value_counts().astype(float)#mean
df["Time_Wasted_on_Social_Media"].value_counts().astype(float)#mean
# Out:
# Time_Wasted_on_Social_Media
# 3.0    1549.0
# 4.0    1543.0
# 2.0    1532.0
# 1.0    1521.0
# 6.0    1518.0
# 5.0    1474.0
# Name: count, dtype: float64

# %%
df["Attendance"]=df["Attendance"].fillna(df["Attendance"].mode()[0])

# %%
df2=["Study_Hours","Class_Size","Sleep_Patterns","Screen_Time","Time_Wasted_on_Social_Media"]
for i in df2:
  df[i]=df[i].fillna(df[i].mean())

# %%
df
# Out:
#        Family_Income Previous_Grades  Attendance Class_Participation  \
# 0            50000.0               0        81.0                   2
# 1            60000.0               0        79.0                   2
# 2            75000.0               2        93.0                   2
# 3            60000.0               0        86.0                   1
# 4            40000.0               3        89.0                   0
# ...              ...             ...         ...                 ...
# 10059        75000.0               0        78.0                   3
# 10060        30000.0               1        79.0                   2
# 10061        30000.0               1        97.0                   2
# 10062        50000.0               1        75.0                   2
# 10063        30000.0               0        80.0                   1
#
#        Study_Hours Major School_Type Financial_Status Parental_Involvement  \
# ...

# %%
df.isna().sum()
# Out:
# Family_Income                  0
# Previous_Grades                0
# Attendance                     0
# Class_Participation            0
# Study_Hours                    0
# Major                          0
# School_Type                    0
# Financial_Status               0
# Parental_Involvement           0
# Educational_Resources          0
# Motivation                     0
# Self_Esteem                    0
# Stress_Levels                  0
# School_Environment             0
# Professor_Quality              0
# Class_Size                     0
# Extracurricular_Activities     0
# Sleep_Patterns                 0
# Nutrition                      0
# Physical_Activity              0
# Screen_Time                    0
# Educational_Tech_Use           0
# Peer_Group                     0
# Study_Space                    0
# Learning_Style                 0
# Tutoring                       0
# Mentoring                      0
# Lack_of_Interest               0
# ...

# %%
df
# Out:
#        Family_Income Previous_Grades  Attendance Class_Participation  \
# 0            50000.0               0        81.0                   2
# 1            60000.0               0        79.0                   2
# 2            75000.0               2        93.0                   2
# 3            60000.0               0        86.0                   1
# 4            40000.0               3        89.0                   0
# ...              ...             ...         ...                 ...
# 10059        75000.0               0        78.0                   3
# 10060        30000.0               1        79.0                   2
# 10061        30000.0               1        97.0                   2
# 10062        50000.0               1        75.0                   2
# 10063        30000.0               0        80.0                   1
#
#        Study_Hours Major School_Type Financial_Status Parental_Involvement  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10064 entries, 0 to 10063
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Family_Income                10064 non-null  float64
#  1   Previous_Grades              10064 non-null  object
#  2   Attendance                   10064 non-null  float64
#  3   Class_Participation          10064 non-null  object
#  4   Study_Hours                  10064 non-null  float64
#  5   Major                        10064 non-null  object
#  6   School_Type                  10064 non-null  object
#  7   Financial_Status             10064 non-null  object
#  8   Parental_Involvement         10064 non-null  object
#  9   Educational_Resources        10064 non-null  object
#  10  Motivation                   10064 non-null  object
#  11  Self_Esteem                  10064 non-null  object
# ...

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[50000.0, 0, 81.0, ..., 1, 2.0, 3],
#        [60000.0, 0, 79.0, ..., 2, 5.0, 0],
#        [75000.0, 2, 93.0, ..., 1, 2.0, 0],
#        ...,
#        [30000.0, 1, 97.0, ..., 0, 3.0, 0],
#        [50000.0, 1, 75.0, ..., 1, 4.0, 2],
#        [30000.0, 0, 80.0, ..., 1, 3.48932910145562, 1]], dtype=object)

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([1, 3, 0, ..., 0, 0, 3], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
df.isna().sum()
# Out:
# Family_Income                  0
# Previous_Grades                0
# Attendance                     0
# Class_Participation            0
# Study_Hours                    0
# Major                          0
# School_Type                    0
# Financial_Status               0
# Parental_Involvement           0
# Educational_Resources          0
# Motivation                     0
# Self_Esteem                    0
# Stress_Levels                  0
# School_Environment             0
# Professor_Quality              0
# Class_Size                     0
# Extracurricular_Activities     0
# Sleep_Patterns                 0
# Nutrition                      0
# Physical_Activity              0
# Screen_Time                    0
# Educational_Tech_Use           0
# Peer_Group                     0
# Study_Space                    0
# Learning_Style                 0
# Tutoring                       0
# Mentoring                      0
# Lack_of_Interest               0
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier(criterion="entropy",max_depth=2)
y = y.astype(int)
clf.fit(x,y)
y_pred=clf.predict(x_test)
y_pred
# Out:
# array([1, 2, 1, ..., 2, 1, 1])

# %%
y_test
# Out:
# array([0, 1, 2, ..., 2, 1, 2], dtype=object)

# %%
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(10,10))
tree.plot_tree(clf)
plt.show()

# %%
from sklearn.metrics import accuracy_score

y_test = y_test.astype(int)
y_pred = y_pred.astype(int)


print(accuracy_score(y_test, y_pred)*100)
# Out:
# 30.264900662251655

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
# Assuming 'y' is the target variable before splitting into train/test sets
y = y.astype(int)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(x_train, y_train)
j_pred = knn.predict(x_test)
j_pred
# Out:
# array([1, 2, 2, ..., 2, 2, 0])

# %%
y_test
# Out:
# array([0, 1, 2, ..., 2, 1, 2])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,j_pred)*100)
# Out:
# 29.072847682119207

# %%
from sklearn.svm import SVC
svc=SVC(kernel="poly")
svc.fit(x_train,y_train)
n_pred=svc.predict(x_test)
n_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,n_pred)*100)
# Out:
# 29.271523178807946

# %%
from sklearn.naive_bayes import GaussianNB
gn=GaussianNB()
gn.fit(x_train,y_train)
f_pred=gn.predict(x_test)
f_pred
# Out:
# array([1, 2, 1, ..., 2, 2, 1])

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,f_pred)*100)
# Out:
# 29.701986754966885

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)
from sklearn.svm import SVC
sv=SVC()
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
from sklearn.metrics import confusion_matrix,accuracy_score

l2=[knn,sv,gnb,dt]
for i in l2:
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  print(i)
  print(confusion_matrix(y_test,y_pred))
  print(accuracy_score(y_test,y_pred)*100)
  print()
# Out:
# KNeighborsClassifier(n_neighbors=7)
# [[376 286 197  20]
#  [390 270 211  13]
#  [375 328 226  17]
#  [122 107  76   6]]
# 29.072847682119207
#
# SVC()
# [[238 462 179   0]
#  [239 477 168   0]
#  [260 528 158   0]
#  [ 79 171  61   0]]
# 28.907284768211923
#
# GaussianNB()
# [[218 400 261   0]
#  [221 404 259   0]
#  [247 424 275   0]
#  [ 74 132 105   0]]
# 29.701986754966885
#
# DecisionTreeClassifier()
# [[270 255 245 109]
#  [258 266 251 109]
#  [279 280 255 132]
#  [ 80  90 101  40]]
# 27.516556291390724

# %%
from sklearn.metrics import ConfusionMatrixDisplay
c1=ConfusionMatrixDisplay.from_predictions(y_test,y_pred)
c1
